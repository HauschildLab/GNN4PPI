# %%
import pandas as pd
import numpy as np
import scipy
from itertools import product

path = 'C:/Users/schirmacher3/PycharmProjects/gnn-for-ppi/final_results/KIRC'

# OUTER EXTENDED
#full
MLP_outer_ext = pd.read_csv(path+'/MLP/results_outer_extended.csv')
ResMLP_outer_ext = pd.read_csv(path+'/ResMLP/results_outer_extended.csv')
DenseMLP_outer_ext = pd.read_csv(path+'/DenseMLP/results_outer_extended.csv')

GCN_outer_ext = pd.read_csv(path+'/GCN/results_outer_extended.csv')
ResGCN_outer_ext = pd.read_csv(path+'/ResGCN/results_outer_extended.csv')
DenseGCN_outer_ext = pd.read_csv(path+'/DenseGCN/results_outer_extended.csv')

GAT_outer_ext = pd.read_csv(path+'/GAT/results_outer_extended.csv')
ResGAT_outer_ext = pd.read_csv(path+'/ResGAT/results_outer_extended.csv')
DenseGAT_outer_ext = pd.read_csv(path+'/DenseGAT/results_outer_extended.csv')

ChebNet_outer_ext = pd.read_csv(path+'/ChebNet/results_outer_extended.csv')
ResChebNet_outer_ext = pd.read_csv(path+'/ResChebNet/results_outer_extended.csv')
DenseChebNet_outer_ext = pd.read_csv(path+'/DenseChebNet/results_outer_extended.csv')

#methyl
mMLP_outer_ext = pd.read_csv(path+'/mMLP/results_outer_extended.csv')
mResMLP_outer_ext = pd.read_csv(path+'/mResMLP/results_outer_extended.csv')
mDenseMLP_outer_ext = pd.read_csv(path+'/mDenseMLP/results_outer_extended.csv')

mGCN_outer_ext = pd.read_csv(path+'/mGCN/results_outer_extended.csv')
mResGCN_outer_ext = pd.read_csv(path+'/mResGCN/results_outer_extended.csv')
mDenseGCN_outer_ext = pd.read_csv(path+'/mDenseGCN/results_outer_extended.csv')

mGAT_outer_ext = pd.read_csv(path+'/mGAT/results_outer_extended.csv')
mResGAT_outer_ext = pd.read_csv(path+'/mResGAT/results_outer_extended.csv')
mDenseGAT_outer_ext = pd.read_csv(path+'/mDenseGAT/results_outer_extended.csv')
#mDenseGAT_outer_ext.drop([10,11,12,13,14], inplace=True)

mChebNet_outer_ext = pd.read_csv(path+'/mChebNet/results_outer_extended.csv')
mResChebNet_outer_ext = pd.read_csv(path+'/mResChebNet/results_outer_extended.csv')
mDenseChebNet_outer_ext = pd.read_csv(path+'/mDenseChebNet/results_outer_extended.csv')

#expr
xMLP_outer_ext = pd.read_csv(path+'/xMLP/results_outer_extended.csv')
xResMLP_outer_ext = pd.read_csv(path+'/xResMLP/results_outer_extended.csv')
xDenseMLP_outer_ext = pd.read_csv(path+'/xDenseMLP/results_outer_extended.csv')

xGCN_outer_ext = pd.read_csv(path+'/xGCN/results_outer_extended.csv')
xResGCN_outer_ext = pd.read_csv(path+'/xResGCN/results_outer_extended.csv')
xDenseGCN_outer_ext = pd.read_csv(path+'/xDenseGCN/results_outer_extended.csv')

xGAT_outer_ext = pd.read_csv(path+'/xGAT/results_outer_extended.csv')
xResGAT_outer_ext = pd.read_csv(path+'/xResGAT/results_outer_extended.csv')
xDenseGAT_outer_ext = pd.read_csv(path+'/xDenseGAT/results_outer_extended.csv')

xChebNet_outer_ext = pd.read_csv(path+'/xChebNet/results_outer_extended.csv')
xResChebNet_outer_ext = pd.read_csv(path+'/xResChebNet/results_outer_extended.csv')
xDenseChebNet_outer_ext = pd.read_csv(path+'/xDenseChebNet/results_outer_extended.csv')


#Rerun
RerunMLP_outer_ext = pd.read_csv(path+'/MLP_rerun/results_outer_extended.csv')
RerunmMLP_outer_ext= pd.read_csv(path+'/mMLP_rerun/results_outer_extended.csv')
RerunxMLP_outer_ext = pd.read_csv(path+'/xMLP_rerun/results_outer_extended.csv')
RerunGCN_outer_ext = pd.read_csv(path+'/GCN_rerun/results_outer_extended.csv')
RerunmGCN_outer_ext = pd.read_csv(path+'/mGCN_rerun/results_outer_extended.csv')
RerunxGCN_outer_ext = pd.read_csv(path+'/xGCN_rerun/results_outer_extended.csv')
RerunGAT_outer_ext = pd.read_csv(path+'/GAT_rerun/results_outer_extended.csv')
RerunmGAT_outer_ext = pd.read_csv(path+'/mGAT_rerun/results_outer_extended.csv')
RerunxGAT_outer_ext = pd.read_csv(path+'/xGAT_rerun/results_outer_extended.csv')

#2MLP models
GCN2MLP_outer_ext = pd.read_csv(path+'/GCN2MLP/results_outer_extended.csv')
ResGCN2MLP_outer_ext = pd.read_csv(path+'/ResGCN2MLP/results_outer_extended.csv')
DenseGCN2MLP_outer_ext = pd.read_csv(path+'/DenseGCN2MLP/results_outer_extended.csv')

GAT2MLP_outer_ext = pd.read_csv(path+'/GAT2MLP/results_outer_extended.csv')
ResGAT2MLP_outer_ext = pd.read_csv(path+'/ResGAT2MLP/results_outer_extended.csv')
DenseGAT2MLP_outer_ext = pd.read_csv(path+'/DenseGAT2MLP/results_outer_extended.csv')

ChebNet2MLP_outer_ext = pd.read_csv(path+'/ChebNet2MLP/results_outer_extended.csv')
ResChebNet2MLP_outer_ext = pd.read_csv(path+'/ResChebNet2MLP/results_outer_extended.csv')
DenseChebNet2MLP_outer_ext = pd.read_csv(path+'/DenseChebNet2MLP/results_outer_extended.csv')


mGCN2MLP_outer_ext = pd.read_csv(path+'/mGCN2MLP/results_outer_extended.csv')
mResGCN2MLP_outer_ext = pd.read_csv(path+'/mResGCN2MLP/results_outer_extended.csv')
mDenseGCN2MLP_outer_ext = pd.read_csv(path+'/mDenseGCN2MLP/results_outer_extended.csv')

mGAT2MLP_outer_ext = pd.read_csv(path+'/mGAT2MLP/results_outer_extended.csv')
mResGAT2MLP_outer_ext = pd.read_csv(path+'/mResGAT2MLP/results_outer_extended.csv')
mDenseGAT2MLP_outer_ext = pd.read_csv(path+'/mDenseGAT2MLP/results_outer_extended.csv')

mChebNet2MLP_outer_ext = pd.read_csv(path+'/mChebNet2MLP/results_outer_extended.csv')
mResChebNet2MLP_outer_ext = pd.read_csv(path+'/mResChebNet2MLP/results_outer_extended.csv')
mDenseChebNet2MLP_outer_ext = pd.read_csv(path+'/mDenseChebNet2MLP/results_outer_extended.csv')


xGCN2MLP_outer_ext = pd.read_csv(path+'/xGCN2MLP/results_outer_extended.csv')
xResGCN2MLP_outer_ext = pd.read_csv(path+'/xResGCN2MLP/results_outer_extended.csv')
xDenseGCN2MLP_outer_ext = pd.read_csv(path+'/xDenseGCN2MLP/results_outer_extended.csv')

xGAT2MLP_outer_ext = pd.read_csv(path+'/xGAT2MLP/results_outer_extended.csv')
xResGAT2MLP_outer_ext = pd.read_csv(path+'/xResGAT2MLP/results_outer_extended.csv')
xDenseGAT2MLP_outer_ext = pd.read_csv(path+'/xDenseGAT2MLP/results_outer_extended.csv')

xChebNet2MLP_outer_ext = pd.read_csv(path+'/xChebNet2MLP/results_outer_extended.csv')
xResChebNet2MLP_outer_ext = pd.read_csv(path+'/xResChebNet2MLP/results_outer_extended.csv')
xDenseChebNet2MLP_outer_ext = pd.read_csv(path+'/xDenseChebNet2MLP/results_outer_extended.csv')

# %%
combinations = list(product(np.arange(10), np.arange(5)))
df = pd.DataFrame(combinations, columns=['test_round', 'es_fold'])

for i in range(50):
    #full data
    df.loc[(df['test_round']== MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'MLP'] = MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResMLP'] = ResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseMLP'] = DenseMLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== GCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== GCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GCN'] = GCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGCN'] = ResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGCN'] = DenseGCN_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== GAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== GAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GAT'] = GAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGAT'] = ResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGAT'] = DenseGAT_outer_ext.iloc[i]['test_mcc']

    #methylation data
    df.loc[(df['test_round']== mMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mMLP'] = mMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResMLP'] = mResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseMLP'] = mDenseMLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== mGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGCN'] = mGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGCN'] = mResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGCN'] = mDenseGCN_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== mGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGAT'] = mGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGAT'] = mResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGAT'] = mDenseGAT_outer_ext.iloc[i]['test_mcc']

    #expression data
    df.loc[(df['test_round']== xMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xMLP'] = xMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResMLP'] = xResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseMLP'] = xDenseMLP_outer_ext.iloc[i]['test_mcc']
    
    df.loc[(df['test_round']== xGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGCN'] = xGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGCN'] = xResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGCN'] = xDenseGCN_outer_ext.iloc[i]['test_mcc']
    
    df.loc[(df['test_round']== xGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGAT'] = xGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGAT'] = xResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGAT'] = xDenseGAT_outer_ext.iloc[i]['test_mcc']

# %%
df
# Out:
#     test_round  es_fold       MLP    ResMLP  DenseMLP       GCN    ResGCN  \
# 0            0        0  0.765824  0.765824  0.765824  0.759567  0.759567
# 1            0        1  0.765824  0.765824  0.765824  0.765824  0.765824
# 2            0        2  0.765824  0.765824  0.765824  0.765824  0.765824
# 3            0        3  0.765824  0.765824  0.765824  0.765824  0.765824
# 4            0        4  0.765824  0.765824  0.765824  0.765824  0.765824
# 5            1        0  0.822655  0.822655  0.822655  0.822655  0.822655
# 6            1        1  0.822655  0.822655  0.822655  0.822655  0.822655
# 7            1        2  0.822655  0.822655  0.822655  0.798490  0.822655
# 8            1        3  0.822655  0.822655  0.822655  0.822655  0.822655
# 9            1        4  0.822655  0.822655  0.822655  0.798490  0.798490
# 10           2        0  0.841767  0.043742  0.841767  0.841767  0.841767
# 11           2        1  0.841767  0.841767  0.841767  0.818067  0.841767
# ...

# %%
# FULL DATA
MLP_vs_ResMLP = scipy.stats.wilcoxon(df['MLP'].to_numpy()-df['ResMLP'].to_numpy())
MLP_vs_DenseMLP = scipy.stats.wilcoxon(df['MLP'].to_numpy()-df['DenseMLP'].to_numpy())
ResMLP_vs_DenseMLP = scipy.stats.wilcoxon(df['ResMLP'].to_numpy()-df['DenseMLP'].to_numpy())

GCN_vs_ResGCN = scipy.stats.wilcoxon(df['GCN'].to_numpy()-df['ResGCN'].to_numpy())
GCN_vs_DenseGCN = scipy.stats.wilcoxon(df['GCN'].to_numpy()-df['DenseGCN'].to_numpy())
ResGCN_vs_DenseGCN = scipy.stats.wilcoxon(df['ResGCN'].to_numpy()-df['DenseGCN'].to_numpy())

GAT_vs_ResGAT = scipy.stats.wilcoxon(df['GAT'].to_numpy()-df['ResGAT'].to_numpy())
GAT_vs_DenseGAT = scipy.stats.wilcoxon(df['GAT'].to_numpy()-df['DenseGAT'].to_numpy())
ResGAT_vs_DenseGAT = scipy.stats.wilcoxon(df['ResGAT'].to_numpy()-df['DenseGAT'].to_numpy())

print('Corrected significanece level:', 0.05/36 )

print('MLP vs. ResMLP: ', MLP_vs_ResMLP.pvalue)
print('MLP vs. DenseMLP: ', MLP_vs_DenseMLP.pvalue)
print('ResMLP vs. DenseMLP: ', ResMLP_vs_DenseMLP.pvalue)

print('GCN vs. ResGCN: ', GCN_vs_ResGCN.pvalue)
print('GCN vs. DenseGCN: ', GCN_vs_DenseGCN.pvalue)
print('ResGCN vs. DenseGCN: ', ResGCN_vs_DenseGCN.pvalue)

print('GAT vs. ResGAT: ', GAT_vs_ResGAT.pvalue)
print('GAT vs. DenseGAT: ', GAT_vs_DenseGAT.pvalue)
print('ResGAT vs. DenseGAT: ', ResGAT_vs_DenseGAT.pvalue)
# Out:
# Corrected significanece level: 0.001388888888888889
# MLP vs. ResMLP:  0.31731050786291415
# MLP vs. DenseMLP:  0.17971249487899976
# ResMLP vs. DenseMLP:  1.0
# GCN vs. ResGCN:  0.937424867850712
# GCN vs. DenseGCN:  0.875138580080403
# ResGCN vs. DenseGCN:  0.6560051321908611
# GAT vs. ResGAT:  0.018737008726159365
# GAT vs. DenseGAT:  7.546948185945826e-05
# ResGAT vs. DenseGAT:  0.43298594421800585

# %%
# METHYLATION DATA
# tried test for MLP here, but not possible as all mcc values in all splits exactly the same
#mMLP_vs_mResMLP = scipy.stats.wilcoxon(df['mMLP'].to_numpy()-df['mResMLP'].to_numpy())
#mMLP_vs_mDenseMLP = scipy.stats.wilcoxon(df['mMLP'].to_numpy()-df['mDenseMLP'].to_numpy())
#mResMLP_vs_mDenseMLP = scipy.stats.wilcoxon(df['mResMLP'].to_numpy()-df['mDenseMLP'].to_numpy())

mGCN_vs_mResGCN = scipy.stats.wilcoxon(df['mGCN'].to_numpy()-df['mResGCN'].to_numpy())
mGCN_vs_mDenseGCN = scipy.stats.wilcoxon(df['mGCN'].to_numpy()-df['mDenseGCN'].to_numpy())
mResGCN_vs_mDenseGCN = scipy.stats.wilcoxon(df['mResGCN'].to_numpy()-df['mDenseGCN'].to_numpy())

mGAT_vs_mResGAT = scipy.stats.wilcoxon(df['mGAT'].to_numpy()-df['mResGAT'].to_numpy())
mGAT_vs_mDenseGAT = scipy.stats.wilcoxon(df['mGAT'].to_numpy()-df['mDenseGAT'].to_numpy())
mResGAT_vs_mDenseGAT = scipy.stats.wilcoxon(df['mResGAT'].to_numpy()-df['mDenseGAT'].to_numpy())

print('Corrected significanece level:', 0.05/36 )

#print('mMLP vs. mResMLP: ', mMLP_vs_mResMLP.pvalue)
#print('mMLP vs. mDenseMLP: ', mMLP_vs_mDenseMLP.pvalue)
#print('mResMLP vs. mDenseMLP: ', mResMLP_vs_mDenseMLP.pvalue)

print('mGCN vs. mResGCN: ', mGCN_vs_mResGCN.pvalue)
print('mGCN vs. mDenseGCN: ', mGCN_vs_mDenseGCN.pvalue)
print('mResGCN vs. mDenseGCN: ', mResGCN_vs_mDenseGCN.pvalue)

print('mGAT vs. mResGAT: ', mGAT_vs_mResGAT.pvalue)
print('mGAT vs. mDenseGAT: ', mGAT_vs_mDenseGAT.pvalue)
print('mResGAT vs. mDenseGAT: ', mResGAT_vs_mDenseGAT.pvalue)
# Out:
# Corrected significanece level: 0.001388888888888889
# mGCN vs. mResGCN:  0.5295490052444518
# mGCN vs. mDenseGCN:  0.010552127178923615
# mResGCN vs. mDenseGCN:  0.06725913065927369
# mGAT vs. mResGAT:  0.8041876578038151
# mGAT vs. mDenseGAT:  4.785794091124314e-06
# mResGAT vs. mDenseGAT:  0.00081235575909106

# %%
# EXPRESSION DATA
xMLP_vs_xResMLP = scipy.stats.wilcoxon(df['xMLP'].to_numpy()-df['xResMLP'].to_numpy())
xMLP_vs_xDenseMLP = scipy.stats.wilcoxon(df['xMLP'].to_numpy()-df['xDenseMLP'].to_numpy())
xResMLP_vs_xDenseMLP = scipy.stats.wilcoxon(df['xResMLP'].to_numpy()-df['xDenseMLP'].to_numpy())

xGCN_vs_xResGCN = scipy.stats.wilcoxon(df['xGCN'].to_numpy()-df['xResGCN'].to_numpy())
xGCN_vs_xDenseGCN = scipy.stats.wilcoxon(df['xGCN'].to_numpy()-df['xDenseGCN'].to_numpy())
xResGCN_vs_xDenseGCN = scipy.stats.wilcoxon(df['xResGCN'].to_numpy()-df['xDenseGCN'].to_numpy())

xGAT_vs_xResGAT = scipy.stats.wilcoxon(df['xGAT'].to_numpy()-df['xResGAT'].to_numpy())
xGAT_vs_xDenseGAT = scipy.stats.wilcoxon(df['xGAT'].to_numpy()-df['xDenseGAT'].to_numpy())
xResGAT_vs_xDenseGAT = scipy.stats.wilcoxon(df['xResGAT'].to_numpy()-df['xDenseGAT'].to_numpy())

print('Corrected significanece level:', 0.05/36 )

print('xMLP vs. xResMLP: ', xMLP_vs_xResMLP.pvalue)
print('xMLP vs. xDenseMLP: ', xMLP_vs_xDenseMLP.pvalue)
print('xResMLP vs. xDenseMLP: ', xResMLP_vs_xDenseMLP.pvalue)

print('xGCN vs. xResGCN: ', xGCN_vs_xResGCN.pvalue)
print('xGCN vs. xDenseGCN: ', xGCN_vs_xDenseGCN.pvalue)
print('xResGCN vs. xDenseGCN: ', xResGCN_vs_xDenseGCN.pvalue)

print('xGAT vs. xResGAT: ', xGAT_vs_xResGAT.pvalue)
print('xGAT vs. xDenseGAT: ', xGAT_vs_xDenseGAT.pvalue)
print('xResGAT vs. xDenseGAT: ', xResGAT_vs_xDenseGAT.pvalue)
# Out:
# Corrected significanece level: 0.001388888888888889
# xMLP vs. xResMLP:  0.3222134482406065
# xMLP vs. xDenseMLP:  0.7758966155985183
# xResMLP vs. xDenseMLP:  0.445107439009679
# xGCN vs. xResGCN:  0.028944204828341025
# xGCN vs. xDenseGCN:  0.0009741001584348182
# xResGCN vs. xDenseGCN:  0.6314231147138947
# xGAT vs. xResGAT:  0.6501478248687451
# xGAT vs. xDenseGAT:  0.9638245625977631
# xResGAT vs. xDenseGAT:  0.44357956002416954

# %%
# BEST AGAINST EACH OTHER
DenseMLP_vs_DenseGCN = scipy.stats.wilcoxon(df['DenseMLP'].to_numpy()-df['DenseGCN'].to_numpy())
DenseMLP_vs_DenseGAT = scipy.stats.wilcoxon(df['DenseMLP'].to_numpy()-df['DenseGAT'].to_numpy())
DenseGCN_vs_DenseGAT = scipy.stats.wilcoxon(df['DenseGCN'].to_numpy()-df['DenseGAT'].to_numpy())

mDenseMLP_vs_mDenseGCN = scipy.stats.wilcoxon(df['mDenseMLP'].to_numpy()-df['mDenseGCN'].to_numpy())
mDenseMLP_vs_mDenseGAT = scipy.stats.wilcoxon(df['mDenseMLP'].to_numpy()-df['mDenseGAT'].to_numpy())
mDenseGCN_vs_mDenseGAT = scipy.stats.wilcoxon(df['mDenseGCN'].to_numpy()-df['mDenseGAT'].to_numpy())

xDenseMLP_vs_xDenseGCN = scipy.stats.wilcoxon(df['xDenseMLP'].to_numpy()-df['xDenseGCN'].to_numpy())
xDenseMLP_vs_xDenseGAT = scipy.stats.wilcoxon(df['xDenseMLP'].to_numpy()-df['xDenseGAT'].to_numpy())
xDenseGCN_vs_xDenseGAT = scipy.stats.wilcoxon(df['xDenseGCN'].to_numpy()-df['xDenseGAT'].to_numpy())


print('DenseMLP vs. DenseGCN: ', DenseMLP_vs_DenseGCN.pvalue)
print('DenseMLP vs. DenseGAT: ', DenseMLP_vs_DenseGAT.pvalue)
print('DenseGCN vs. DenseGAT: ', DenseGCN_vs_DenseGAT.pvalue)

print('mDenseMLP vs. mDenseGCN: ', mDenseMLP_vs_mDenseGCN.pvalue)
print('mDenseMLP vs. mDenseGAT: ', mDenseMLP_vs_mDenseGAT.pvalue)
print('mDenseGCN vs. mDenseGAT: ', mDenseGCN_vs_mDenseGAT.pvalue)

print('xDenseMLP vs. xDenseGCN: ', xDenseMLP_vs_xDenseGCN.pvalue)
print('xDenseMLP vs. xDenseGAT: ', xDenseMLP_vs_xDenseGAT.pvalue)
print('xDenseGCN vs. xDenseGAT: ', xDenseGCN_vs_xDenseGAT.pvalue)
# Out:
# DenseMLP vs. DenseGCN:  0.14197368784068543
# DenseMLP vs. DenseGAT:  0.0006201272508441838
# DenseGCN vs. DenseGAT:  0.15247392284648287
# mDenseMLP vs. mDenseGCN:  0.0006500242387180628
# mDenseMLP vs. mDenseGAT:  7.053682222679291e-06
# mDenseGCN vs. mDenseGAT:  0.170065301766252
# xDenseMLP vs. xDenseGCN:  7.546683182364461e-10
# xDenseMLP vs. xDenseGAT:  1.0223799694166888e-09
# xDenseGCN vs. xDenseGAT:  0.003647944428434541

# %%
DenseMLP_vs_mDenseMLP = scipy.stats.wilcoxon(df['DenseMLP'].to_numpy()-df['mDenseMLP'].to_numpy())
DenseMLP_vs_xDenseMLP = scipy.stats.wilcoxon(df['DenseMLP'].to_numpy()-df['xDenseMLP'].to_numpy())
mDenseMLP_vs_xDenseMLP = scipy.stats.wilcoxon(df['mDenseMLP'].to_numpy()-df['xDenseMLP'].to_numpy())

print('DenseMLP vs. mDenseMLP: ', DenseMLP_vs_mDenseMLP.pvalue)
print('DenseMLP vs. xDenseMLP: ', DenseMLP_vs_xDenseMLP.pvalue)
print('mDenseMLP vs. xDenseMLP: ', mDenseMLP_vs_xDenseMLP.pvalue)
# Out:
# DenseMLP vs. mDenseMLP:  0.17971249487899976
# DenseMLP vs. xDenseMLP:  2.2827187445987576e-08
# mDenseMLP vs. xDenseMLP:  1.531261091533056e-08

# %% [markdown]
# # Final Tests for paper

# %% [markdown]
# ## KIRC

# %%
combinations = list(product(np.arange(10), np.arange(5)))
df = pd.DataFrame(combinations, columns=['test_round', 'es_fold'])

for i in range(50):
    #full data
    df.loc[(df['test_round']== RerunMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'MLP'] = RerunMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GCN'] = RerunGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GAT'] = RerunGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ChebNet'] = ChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== GCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== GCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GCN2MLP'] = GCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== GAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== GAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'GAT2MLP'] = GAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ChebNet2MLP'] = ChebNet2MLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== ResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResMLP'] = ResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGCN'] = ResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGAT'] = ResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResChebNet'] = ResChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGCN2MLP'] = ResGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResGAT2MLP'] = ResGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== ResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== ResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'ResChebNet2MLP'] = ResChebNet2MLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== DenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseMLP'] = DenseMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGCN'] = DenseGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGAT'] = DenseGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseChebNet'] = DenseChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGCN2MLP'] = DenseGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseGAT2MLP'] = DenseGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== DenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== DenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'DenseChebNet2MLP'] = DenseChebNet2MLP_outer_ext.iloc[i]['test_mcc']



    #methylation data
    df.loc[(df['test_round']== RerunmMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunmMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mMLP'] = RerunmMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunmGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunmGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGCN'] = RerunmGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunmGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunmGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGAT'] = RerunmGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mChebNet'] = mChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGCN2MLP'] = mGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mGAT2MLP'] = mGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mChebNet2MLP'] = mChebNet2MLP_outer_ext.iloc[i]['test_mcc']


    df.loc[(df['test_round']== mResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResMLP'] = mResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGCN'] = mResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGAT'] = mResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResChebNet'] = mResChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGCN2MLP'] = mResGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResGAT2MLP'] = mResGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mResChebNet2MLP'] = mResChebNet2MLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== mDenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseMLP'] = mDenseMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGCN'] = mDenseGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGAT'] = mDenseGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseChebNet'] = mDenseChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGCN2MLP'] = mDenseGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGAT2MLP'] = mDenseGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseChebNet2MLP'] = mDenseChebNet2MLP_outer_ext.iloc[i]['test_mcc']


    #expression data
    df.loc[(df['test_round']== RerunxMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunxMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xMLP'] = RerunxMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunxGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunxGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGCN'] = RerunxGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== RerunxGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== RerunxGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGAT'] = RerunxGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xChebNet'] = xChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGCN2MLP'] = xGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGAT2MLP'] = xGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xChebNet2MLP'] = xChebNet2MLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== xResMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResMLP'] = xResMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGCN'] = xResGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGAT'] = xResGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResChebNet'] = xResChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGCN2MLP'] = xResGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResGAT2MLP'] = xResGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xResChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xResChebNet2MLP'] = xResChebNet2MLP_outer_ext.iloc[i]['test_mcc']

    df.loc[(df['test_round']== xDenseMLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseMLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseMLP'] = xDenseMLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGCN_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGCN_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGCN'] = xDenseGCN_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGAT'] = xDenseGAT_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseChebNet_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseChebNet_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseChebNet'] = xDenseChebNet_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGCN2MLP'] = xDenseGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseGAT2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseGAT2MLP'] = xDenseGAT2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== xDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xDenseChebNet2MLP'] = xDenseChebNet2MLP_outer_ext.iloc[i]['test_mcc']



#special case: inner test round with patt for hyp selection -> several outer results (same val auc)
for i in range(50, 55):
    df.loc[(df['test_round']== xGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== xGCN2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'xGCN2MLP'] = xGCN2MLP_outer_ext.iloc[i]['test_mcc']
    df.loc[(df['test_round']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseGAT_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseGAT'] = mDenseGAT_outer_ext.iloc[i]['test_mcc']

for i in range(50, 65):
    df.loc[(df['test_round']== mDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/dataset_test_round']) & (df['es_fold']== mDenseChebNet2MLP_outer_ext.iloc[i]['config/train_loop_config/es_folds']), 'mDenseChebNet2MLP'] = mDenseChebNet2MLP_outer_ext.iloc[i]['test_mcc']

# %%
df
# Out:
#     test_round  es_fold       MLP       GCN       GAT   ChebNet   GCN2MLP  \
# 0            0        0  0.765824  0.759567  0.732221  0.784700  0.765824
# 1            0        1  0.765824  0.765824  0.778996  0.765824  0.765824
# 2            0        2  0.765824  0.765824  0.765824  0.765824  0.765824
# 3            0        3  0.765824  0.765824  0.765824  0.765824  0.765824
# 4            0        4  0.765824  0.746994  0.765824  0.765824  0.765824
# 5            1        0  0.822655  0.822655  0.841767  0.822655  0.822655
# 6            1        1  0.822655  0.822655  0.775144  0.822655  0.822655
# 7            1        2  0.822655  0.822655  0.730485  0.822655  0.822655
# 8            1        3  0.822655  0.822655  0.822655  0.822655  0.822655
# 9            1        4  0.822655  0.822655  0.798490  0.822655  0.822655
# 10           2        0  0.841767  0.841767  0.841767  0.841767  0.841767
# 11           2        1  0.841767  0.841767  0.043742  0.841767  0.841767
# ...

# %%
# Mean over CV folds for ES (not independent!)
df_fold = df.groupby('test_round').mean()

# %%
df_fold
# Out:
#             es_fold       MLP       GCN       GAT   ChebNet   GCN2MLP  \
# test_round
# 0               2.0  0.765824  0.760807  0.761738  0.769599  0.765824
# 1               2.0  0.822655  0.822655  0.793708  0.822655  0.822655
# 2               2.0  0.841767  0.832287  0.667942  0.841767  0.841767
# 3               2.0  0.746994  0.731294  0.741761  0.746994  0.746994
# 4               2.0  0.822655  0.806316  0.439553  0.822655  0.822655
# 5               2.0  0.803638  0.726037  0.692186  0.803638  0.803638
# 6               2.0  0.803638  0.803638  0.642943  0.803638  0.803638
# 7               2.0  0.746994  0.735713  0.649694  0.746994  0.746994
# 8               2.0  0.803638  0.803638  0.766738  0.803638  0.803638
# 9               2.0  0.860990  0.857146  0.829029  0.860990  0.860990
#
#              GAT2MLP  ChebNet2MLP    ResMLP    ResGCN  ...  xResGCN2MLP  \
# test_round                                             ...
# ...

# %%
# Experiment 1) MLP vs. GNNs

#full data
MLP_vs_GCN = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['GCN'].to_numpy())
MLP_vs_GAT = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['GAT'].to_numpy())
MLP_vs_ChebNet = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['ChebNet'].to_numpy())
MLP_vs_GCN2MLP = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['GCN2MLP'].to_numpy())
MLP_vs_GAT2MLP = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['GAT2MLP'].to_numpy())
MLP_vs_ChebNet2MLP = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['ChebNet2MLP'].to_numpy())


print('MLP vs. GCN: ', MLP_vs_GCN.pvalue)
print('MLP vs. GAT: ', MLP_vs_GAT.pvalue)
print('MLP vs. ChebNet: ', MLP_vs_ChebNet.pvalue)
print('MLP vs. GCN2MLP: ', MLP_vs_GCN2MLP.pvalue)
print('MLP vs. GAT2MLP: ', MLP_vs_GAT2MLP.pvalue)
print('MLP vs. ChebNet2MLP: ', MLP_vs_ChebNet2MLP.pvalue)

#print('\nMLP and GCN2MLP same?', df_fold['MLP'].equals(df_fold['GCN2MLP']))
#print('MLP and ChebNet2MLP same?', df_fold['MLP'].equals(df_fold['ChebNet2MLP']), '\n')

#methylation data
mMLP_vs_mGCN = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mGCN'].to_numpy())
mMLP_vs_mGAT = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mGAT'].to_numpy())
mMLP_vs_mChebNet = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mChebNet'].to_numpy())
mMLP_vs_mGCN2MLP = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mGCN2MLP'].to_numpy())
mMLP_vs_mGAT2MLP = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mGAT2MLP'].to_numpy())
mMLP_vs_mChebNet2MLP = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['mChebNet2MLP'].to_numpy())


print('\nmMLP vs. mGCN: ', mMLP_vs_mGCN.pvalue)
print('mMLP vs. mGAT: ', mMLP_vs_mGAT.pvalue)
print('mMLP vs. mChebNet: ', mMLP_vs_mChebNet.pvalue)
print('mMLP vs. mGCN2MLP: ', mMLP_vs_mGCN2MLP.pvalue)
print('mMLP vs. mGAT2MLP: ', mMLP_vs_mGAT2MLP.pvalue)
print('mMLP vs. mChebNet2MLP: ', mMLP_vs_mChebNet2MLP.pvalue)

#print('\nmMLP and mChebNet2MLP same?', df_fold['mMLP'].equals(df_fold['mChebNet2MLP']), '\n')

#expression data
xMLP_vs_xGCN = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xGCN'].to_numpy())
xMLP_vs_xGAT = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xGAT'].to_numpy())
xMLP_vs_xChebNet = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xChebNet'].to_numpy())
xMLP_vs_xGCN2MLP = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xGCN2MLP'].to_numpy())
xMLP_vs_xGAT2MLP = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xGAT2MLP'].to_numpy())
xMLP_vs_xChebNet2MLP = scipy.stats.wilcoxon(df_fold['xMLP'].to_numpy()-df_fold['xChebNet2MLP'].to_numpy())


print('\nxMLP vs. xGCN: ', xMLP_vs_xGCN.pvalue)
print('xMLP vs. xGAT: ', xMLP_vs_xGAT.pvalue)
print('xMLP vs. xChebNet: ', xMLP_vs_xChebNet.pvalue)
print('xMLP vs. xGCN2MLP: ', xMLP_vs_xGCN2MLP.pvalue)
print('xMLP vs. xGAT2MLP: ', xMLP_vs_xGAT2MLP.pvalue)
print('xMLP vs. xChebNet2MLP: ', xMLP_vs_xChebNet2MLP.pvalue)

print('\np-value:', 0.05)
print('p-value with Bonferroni correction (within experiment):', 0.05/21)
# Out:
# c:\Users\schirmacher3\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_wilcoxon.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# MLP vs. GCN:  0.015625
# MLP vs. GAT:  0.001953125
# MLP vs. ChebNet:  1.0
# MLP vs. GCN2MLP:  1.0
# MLP vs. GAT2MLP:  0.0625
# MLP vs. ChebNet2MLP:  1.0
#
# mMLP vs. mGCN:  0.125
# mMLP vs. mGAT:  0.00390625
# mMLP vs. mChebNet:  1.0
# mMLP vs. mGCN2MLP:  1.0
# mMLP vs. mGAT2MLP:  0.5
# mMLP vs. mChebNet2MLP:  1.0
#
# xMLP vs. xGCN:  0.001953125
# xMLP vs. xGAT:  0.001953125
# xMLP vs. xChebNet:  0.01953125
# xMLP vs. xGCN2MLP:  0.3125
# xMLP vs. xGAT2MLP:  0.013671875
# xMLP vs. xChebNet2MLP:  0.001953125
#
# p-value: 0.05
# p-value with Bonferroni correction (within experiment): 0.002380952380952381

# %%
# Experiment 2) full vs. methyl vs. expr (for MLP and GNNs)

MLP_vs_mMLP = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['mMLP'].to_numpy())
MLP_vs_xMLP = scipy.stats.wilcoxon(df_fold['MLP'].to_numpy()-df_fold['xMLP'].to_numpy())
mMLP_vs_xMLP = scipy.stats.wilcoxon(df_fold['mMLP'].to_numpy()-df_fold['xMLP'].to_numpy())

GNNs_vs_mGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'], df_fold['GAT'], df_fold['ChebNet'],df_fold['GCN2MLP'], df_fold['GAT2MLP'],df_fold['ChebNet2MLP']]).to_numpy()-pd.concat([df_fold['mGCN'], df_fold['mGAT'], df_fold['mChebNet'],df_fold['mGCN2MLP'], df_fold['mGAT2MLP'],df_fold['mChebNet2MLP']]))
GNNs_vs_xGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'], df_fold['GAT'], df_fold['ChebNet'],df_fold['GCN2MLP'], df_fold['GAT2MLP'],df_fold['ChebNet2MLP']]).to_numpy()-pd.concat([df_fold['xGCN'], df_fold['xGAT'], df_fold['xChebNet'],df_fold['xGCN2MLP'], df_fold['xGAT2MLP'],df_fold['xChebNet2MLP']]))
mGNNs_vs_xGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['xGCN'], df_fold['xGAT'], df_fold['xChebNet'],df_fold['xGCN2MLP'], df_fold['xGAT2MLP'],df_fold['xChebNet2MLP']]).to_numpy()-pd.concat([df_fold['mGCN'], df_fold['mGAT'], df_fold['mChebNet'],df_fold['mGCN2MLP'], df_fold['mGAT2MLP'],df_fold['mChebNet2MLP']]))


print('MLP vs. mMLP: ', MLP_vs_mMLP.pvalue)
print('MLP vs. xMLP: ', MLP_vs_xMLP.pvalue)
print('mMLP vs. xMLP: ', mMLP_vs_xMLP.pvalue)

print('\nMLP and mMLP same?', df_fold['MLP'].equals(df_fold['mMLP']), '\n')

print('GNNs vs. mGNNs: ', GNNs_vs_mGNNs.pvalue)
print('GNNs vs. xGNNs: ', GNNs_vs_xGNNs.pvalue )
print('mGNNs vs. xGNNs: ', mGNNs_vs_xGNNs.pvalue)


print('\np-value:', 0.05)
print('p-value with Bonferroni correction (within experiment):', 0.05/6)
# Out:
# MLP vs. mMLP:  1.0
# MLP vs. xMLP:  0.00390625
# mMLP vs. xMLP:  0.00390625
#
# MLP and mMLP same? True
#
# GNNs vs. mGNNs:  0.05560727262442432
# GNNs vs. xGNNs:  1.4719513388497698e-10
# mGNNs vs. xGNNs:  1.0926538545280055e-10
#
# p-value: 0.05
# p-value with Bonferroni correction (within experiment): 0.008333333333333333

# %%
# Experiment 3a) GCN vs. GAT vs. ChebNet (over all data modalities)
GCN_vs_GAT_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'], df_fold['mGCN'], df_fold['xGCN']]).to_numpy()-pd.concat([df_fold['GAT'], df_fold['mGAT'], df_fold['xGAT']]).to_numpy())
GCN_vs_ChebNet_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'], df_fold['mGCN'], df_fold['xGCN']]).to_numpy()-pd.concat([df_fold['ChebNet'], df_fold['mChebNet'], df_fold['xChebNet']]).to_numpy())
GAT_vs_ChebNet_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['GAT'], df_fold['mGAT'], df_fold['xGAT']]).to_numpy()-pd.concat([df_fold['ChebNet'], df_fold['mChebNet'], df_fold['xChebNet']]).to_numpy())



print('GCN vs. GAT (all data): ', GCN_vs_GAT_all_data.pvalue)
print('GCN vs. ChebNet (all data): ', GCN_vs_ChebNet_all_data.pvalue)
print('GAT vs. ChebNet (all data): ', GAT_vs_ChebNet_all_data.pvalue)

print('\np-value:', 0.05)
print('p-value with Bonferroni correction (within experiment):', 0.05/3)
# Out:
# GCN vs. GAT (all data):  0.15188691951334476
# GCN vs. ChebNet (all data):  2.6987022409679446e-05
# GAT vs. ChebNet (all data):  2.5630832507250074e-06
#
# p-value: 0.05
# p-value with Bonferroni correction (within experiment): 0.016666666666666666

# %%
# Experiment 3b) readout functions (over all data modalities)
GCN_vs_GCN2MLP_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'], df_fold['mGCN'], df_fold['xGCN']]).to_numpy()-pd.concat([df_fold['GCN2MLP'], df_fold['mGCN2MLP'], df_fold['xGCN2MLP']]).to_numpy())
GAT_vs_GAT2MLP_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['GAT'], df_fold['mGAT'], df_fold['xGAT']]).to_numpy()-pd.concat([df_fold['GAT2MLP'], df_fold['mGAT2MLP'], df_fold['xGAT2MLP']]).to_numpy())
ChebNet_vs_ChebNet2MLP_all_data = scipy.stats.wilcoxon(pd.concat([df_fold['ChebNet'], df_fold['mChebNet'], df_fold['xChebNet']]).to_numpy()-pd.concat([df_fold['ChebNet2MLP'], df_fold['mChebNet2MLP'], df_fold['xChebNet2MLP']]).to_numpy())


print('GCN vs. GCN2MLP (all data): ', GCN_vs_GCN2MLP_all_data.pvalue)
print('GAT vs. GAT2MLP (all data): ', GAT_vs_GAT2MLP_all_data.pvalue)
print('ChebNet vs. ChebNet2MLP (all data): ', ChebNet_vs_ChebNet2MLP_all_data.pvalue)

print('\np-value:', 0.05)
print('p-value with Bonferroni correction (within experiment):', 0.05/3)
# Out:
# GCN vs. GCN2MLP (all data):  8.534902871042814e-05
# GAT vs. GAT2MLP (all data):  4.228408847246096e-06
# ChebNet vs. ChebNet2MLP (all data):  0.030327342511675306
#
# p-value: 0.05
# p-value with Bonferroni correction (within experiment): 0.016666666666666666

# %%
# Experiment 3c) Plain vs. Res vs. Dense (for MLP and GNNs) (over all data modalities)


PlainMLP_vs_ResMLP = scipy.stats.wilcoxon(pd.concat([df_fold['MLP'],df_fold['mMLP'],df_fold['xMLP']]).to_numpy()-pd.concat([df_fold['ResMLP'],df_fold['mResMLP'],df_fold['xResMLP']]).to_numpy())
PlainMLP_vs_DenseMLP = scipy.stats.wilcoxon(pd.concat([df_fold['MLP'],df_fold['mMLP'],df_fold['xMLP']]).to_numpy()-pd.concat([df_fold['DenseMLP'],df_fold['mDenseMLP'],df_fold['xDenseMLP']]).to_numpy())
ResMLP_vs_DenseMLP = scipy.stats.wilcoxon(pd.concat([df_fold['ResMLP'],df_fold['mResMLP'],df_fold['xResMLP']]).to_numpy()-pd.concat([df_fold['DenseMLP'],df_fold['mDenseMLP'],df_fold['xDenseMLP']]).to_numpy())

PlainGNNs_vs_ResGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'],df_fold['mGCN'],df_fold['xGCN'], df_fold['GAT'], df_fold['mGAT'], df_fold['xGAT'], df_fold['ChebNet'], df_fold['mChebNet'], df_fold['xChebNet'], df_fold['GCN2MLP'], df_fold['mGCN2MLP'], df_fold['xGCN2MLP'], df_fold['GAT2MLP'], df_fold['mGAT2MLP'], df_fold['xGAT2MLP'], df_fold['ChebNet2MLP'], df_fold['mChebNet2MLP'], df_fold['xChebNet2MLP']]).to_numpy()-pd.concat([df_fold['ResGCN'],df_fold['mResGCN'],df_fold['xResGCN'], df_fold['ResGAT'], df_fold['mResGAT'], df_fold['xResGAT'], df_fold['ResChebNet'], df_fold['mResChebNet'], df_fold['xResChebNet'], df_fold['ResGCN2MLP'], df_fold['mResGCN2MLP'], df_fold['xResGCN2MLP'], df_fold['ResGAT2MLP'], df_fold['mResGAT2MLP'], df_fold['xResGAT2MLP'], df_fold['ResChebNet2MLP'], df_fold['mResChebNet2MLP'], df_fold['xResChebNet2MLP']]))
PlainGNNs_vs_DenseGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['GCN'],df_fold['mGCN'],df_fold['xGCN'], df_fold['GAT'], df_fold['mGAT'], df_fold['xGAT'], df_fold['ChebNet'], df_fold['mChebNet'], df_fold['xChebNet'], df_fold['GCN2MLP'], df_fold['mGCN2MLP'], df_fold['xGCN2MLP'], df_fold['GAT2MLP'], df_fold['mGAT2MLP'], df_fold['xGAT2MLP'], df_fold['ChebNet2MLP'], df_fold['mChebNet2MLP'], df_fold['xChebNet2MLP']]).to_numpy()-pd.concat([df_fold['DenseGCN'],df_fold['mDenseGCN'],df_fold['xDenseGCN'], df_fold['DenseGAT'], df_fold['mDenseGAT'], df_fold['xDenseGAT'], df_fold['DenseChebNet'], df_fold['mDenseChebNet'], df_fold['xDenseChebNet'], df_fold['DenseGCN2MLP'], df_fold['mDenseGCN2MLP'], df_fold['xDenseGCN2MLP'], df_fold['DenseGAT2MLP'], df_fold['mDenseGAT2MLP'], df_fold['xDenseGAT2MLP'], df_fold['DenseChebNet2MLP'], df_fold['mDenseChebNet2MLP'], df_fold['xDenseChebNet2MLP']]))
ResGNNs_vs_DenseGNNs = scipy.stats.wilcoxon(pd.concat([df_fold['DenseGCN'],df_fold['mDenseGCN'],df_fold['xDenseGCN'], df_fold['DenseGAT'], df_fold['mDenseGAT'], df_fold['xDenseGAT'], df_fold['DenseChebNet'], df_fold['mDenseChebNet'], df_fold['xDenseChebNet'], df_fold['DenseGCN2MLP'], df_fold['mDenseGCN2MLP'], df_fold['xDenseGCN2MLP'], df_fold['DenseGAT2MLP'], df_fold['mDenseGAT2MLP'], df_fold['xDenseGAT2MLP'], df_fold['DenseChebNet2MLP'], df_fold['mDenseChebNet2MLP'], df_fold['xDenseChebNet2MLP']]).to_numpy()-pd.concat([df_fold['ResGCN'],df_fold['mResGCN'],df_fold['xResGCN'], df_fold['ResGAT'], df_fold['mResGAT'], df_fold['xResGAT'], df_fold['ResChebNet'], df_fold['mResChebNet'], df_fold['xResChebNet'], df_fold['ResGCN2MLP'], df_fold['mResGCN2MLP'], df_fold['xResGCN2MLP'], df_fold['ResGAT2MLP'], df_fold['mResGAT2MLP'], df_fold['xResGAT2MLP'], df_fold['ResChebNet2MLP'], df_fold['mResChebNet2MLP'], df_fold['xResChebNet2MLP']]))

print('PlainMLP vs. ResMLP: ', PlainMLP_vs_ResMLP.pvalue)
print('PlainMLP vs. DenseMLP: ', PlainMLP_vs_DenseMLP.pvalue)
print('ResMLP vs. DenseMLP: ', ResMLP_vs_DenseMLP.pvalue, '\n')


print('GNNs vs. ResGNNs: ', PlainGNNs_vs_ResGNNs.pvalue)
print('GNNs vs. DenseGNNs: ', PlainGNNs_vs_DenseGNNs.pvalue )
print('ResGNNs vs. DenseGNNs: ', ResGNNs_vs_DenseGNNs.pvalue)


print('\np-value:', 0.05)
print('p-value with Bonferroni correction (within experiment):', 0.05/6)
# Out:
# PlainMLP vs. ResMLP:  0.6777720243818599
# PlainMLP vs. DenseMLP:  0.6360148778759422
# ResMLP vs. DenseMLP:  0.7536837177261574
#
# GNNs vs. ResGNNs:  0.9864183665214684
# GNNs vs. DenseGNNs:  0.21107019831244977
# ResGNNs vs. DenseGNNs:  0.7058331096022299
#
# p-value: 0.05
# p-value with Bonferroni correction (within experiment): 0.008333333333333333
